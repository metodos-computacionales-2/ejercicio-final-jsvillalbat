# %%
import matplotlib.pyplot as plt
import numpy as np

datos = np.loadtxt('datos-2.4.txt')
plt.plot(datos[:,1], datos[:,2])
periodo = np.loadtxt("puntos.dat")
x= 0.0;
for i in range(len(periodo)):
    if(periodo[i]!=0):
        plt.scatter(datos[:,1][i], periodo[i], c = "r")
        x= periodo[i]
        
print(x)
print(datos)
# Out:
# -3.08037
# [[ 0.00000e+00  1.99980e-01 -1.98669e-03]
#  [ 1.00000e-02  1.99942e-01 -3.80342e-03]
#  [ 2.00000e-02  1.99888e-01 -5.45086e-03]
#  ...
#  [ 9.97000e+00 -1.67613e+00 -1.51542e+00]
#  [ 9.98000e+00 -1.69103e+00 -1.48937e+00]
#  [ 9.99000e+00 -1.70566e+00 -1.46331e+00]]

# %%
datos_1= np.loadtxt('datos-1.44.txt')
plt.plot(datos_1[:,1], datos_1[:,2])

# %%
datos_2 = np.loadtxt('datos-1.465.txt')
plt.plot(datos_2[:,1], datos_2[:,2])

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
datos = np.loadtxt('datos-1.4.txt')
plt.plot(datos[:,1], datos[:,2])
t = datos[:,0]
for i in range(len(t)):
    clear_output(wait = True)
    plt.plot(datos[:i,1],datos[:i,2])
    plt.title('Posicion en {}'.format(round(t[i],3)))
    plt.plot(datos[:i,1],datos [:i,2])
    plt.savefig("1.4.png")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
datos_2 = np.loadtxt('datos-1.44.txt')
plt.plot(datos_2[:,1], datos_2[:,2])
t = datos[:,0]
for i in range(len(t)):
    clear_output(wait = True)
    plt.plot(datos_2[:i,1],datos_2[:i,2])
    plt.title('Posicion en {}'.format(round(t[i],3)))
    plt.plot(datos_2[:i,1],datos_2[:i,2])
    plt.savefig("1.44.png")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
datos_3 = np.loadtxt('datos-1.465.txt')
plt.plot(datos_3[:,1], datos_3[:,2])
t = datos[:,0]
for i in range(len(t)):
    clear_output(wait = True)
    plt.plot(datos_3[:i,1],datos_3[:i,2])
    plt.title('Posicion en {}'.format(round(t[i],3)))
    plt.plot(datos_3[:i,1],datos_3[:i,2])
    plt.savefig("1.465.png")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
datos_4 = np.loadtxt('datos-2.4.txt')
plt.plot(datos_4[:,1], datos_4[:,2])
t = datos[:,0]
for i in range(len(t)):
    clear_output(wait = True)
    plt.plot(datos_4[:i,1],datos_4[:i,2])
    plt.title('Posicion en {}'.format(round(t[i],3)))
    plt.plot(datos_4[:i,1],datos_4[:i,2])
    plt.savefig("CambioFd.png")
    plt.show()

# %% [markdown]
# ### A medida que aumenta el Fd la curva disminuye la concavidad. Si el valor del periodo es muy grande el sistema puede tornarse inestable
